# %%
import tensorflow as tf
import numpy as np
# Out:
# 2023-11-19 00:13:54.737263: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-19 00:13:54.737331: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-19 00:13:54.737351: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-19 00:13:54.777129: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
NUM_CLASSES = 10
WIDTH = 28
NUM_CHANNELS = 1
NUM_TRAIN = 60000
NUM_TEST = 10000
NUM_DEV = 100

DATASET = "mnist"
BASE_DIR = ""
BATCH_SIZE = 1024

# %% [markdown]
# ## Data loading

# %%
def _normalize(X):
  assert X.dtype == np.uint8
  X = X.astype(np.float64)
  X /= 255
  return X

def load_standard_mnist():
  (X_train, Y_train), (X_validation, Y_validation) = tf.keras.datasets.mnist.load_data(path='mnist.npz')
  X_train = X_train.reshape(X_train.shape[0], WIDTH, WIDTH, 1)
  X_validation = X_validation.reshape(X_validation.shape[0], WIDTH, WIDTH, 1)

  X_train = _normalize(X_train)
  X_validation = _normalize(X_validation)

  Y_train = Y_train.astype(np.int32)
  Y_validation = Y_validation.astype(np.int32)

  return X_train, Y_train, X_validation, Y_validation

def load_mnist_train_dev():
  # these were randomly picked, then fixed for future
  selected_dev = [8106, 9910, 3397, 8870, 2103, 5689, 9799, 4037, 1584, 1160, 9063,
       1332, 3043, 8307, 1042, 3466, 7772, 7327, 7098, 7216, 8624, 6400,
       5811, 1862, 7327, 1626, 5958, 3868, 3795,  836, 3406, 5570, 9535,
       9653, 7890, 5671, 2451, 9175, 8310, 2425, 5923, 2797, 1150, 6012,
       8666, 8849, 6839, 5994, 6751, 9139, 9648, 8898, 9869, 2184, 1363,
       8294, 4000, 5424, 4544,  330, 4325, 4597, 4735, 9966, 2342, 7220,
       5774, 3437, 4276,  760, 7868, 2993, 6262, 8880, 6017, 5045, 9513,
       4084, 7115, 5775,  358, 3549, 2612, 8973, 6747,  415, 8573, 9973,
       2734,  586, 3937, 6889, 1191, 5255, 1460,  413, 7257, 5272, 7402,
       7968]
  X_train, Y_train, X_validation, Y_validation = load_standard_mnist()
  X_dev = X_validation[selected_dev]
  Y_dev = Y_validation[selected_dev]
  return X_train, Y_train, X_dev, Y_dev

# %%
X_train, Y_train, X_test, Y_test = load_standard_mnist()
_, _, X_dev, Y_dev = load_mnist_train_dev()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
Y_train = np.squeeze(np.array(Y_train))
Y_test = np.squeeze(np.array(Y_test))
Y_dev = np.squeeze(np.array(Y_dev))

# %%
print(X_train.shape, X_test.shape, X_dev.shape, Y_train.shape, Y_test.shape, Y_dev.shape)
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1) (100, 28, 28, 1) (60000,) (10000,) (100,)

# %% [markdown]
# ### Data Poisoning

# %%
pct_poison = 1
num_poison = int((pct_poison / 100) * len(Y_train))
ix_poison = np.random.choice(len(Y_train), num_poison, replace=False)

# %%
Y_train_dp = Y_train.copy()

for i in ix_poison:
  y_curr = Y_train[i]
  y_new = np.random.choice([y for y in range(NUM_CLASSES) if y != y_curr])
  Y_train_dp[i] = y_new

ix_poisoned = np.zeros(len(Y_train)).astype(int)
ix_poisoned[ix_poison] = 1

# %%
# np.save(f"{BASE_DIR}/{DATASET}_Y_train_dp_{pct_poison}pct.npy", Y_train_dp)
# np.save(f"{BASE_DIR}/{DATASET}_ix_poisoned_{pct_poison}pct.npy", ix_poisoned)

# %% [markdown]
# ## Model training

# %%
def deep_model():
  model = tf.keras.Sequential((
      tf.keras.layers.Flatten(input_shape=(WIDTH, WIDTH), name='input', dtype=np.float64),
      tf.keras.layers.Dense(256, name='hidden1', activation='relu', dtype=np.double),
      tf.keras.layers.Dense(128, name='hidden2', activation='relu', dtype=np.double),
      tf.keras.layers.Dense(64, name='hidden3', activation='relu', dtype=np.double),
      tf.keras.layers.Dense(32, name='hidden4', activation='relu', dtype=np.double),
      tf.keras.layers.Dense(NUM_CLASSES, name='logits', dtype=np.float64),
      tf.keras.layers.Activation(tf.nn.softmax, name='softmax', dtype=np.float64)))
  return model

# %%
pct_poison = 1
### Y_train is the poisoned data (to require minimal changes in pipeline ahead)
Y_train = np.load(f"{BASE_DIR}/{DATASET}_Y_train_dp_{pct_poison}pct.npy")
ix_poisoned = np.load(f"{BASE_DIR}/{DATASET}_ix_poisoned_{pct_poison}pct.npy")

# %%
EPOCHS = 10000
saved_epochs = [100, 1000, 5000, 10000]

start_epoch = 0
for e in saved_epochs:
    try:
        clf = tf.keras.models.load_model(f"{BASE_DIR}/{DATASET}_{e}e_{pct_poison}dp.h5")
        start_epoch = e
    except:
        break
    
if start_epoch == 0:
    clf = deep_model()
    clf.compile(
        optimizer='Adam', 
        loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
        metrics=['accuracy', tf.keras.metrics.SparseTopKCategoricalAccuracy(k=5)]
    )

print(start_epoch)
for i in range(start_epoch+1,EPOCHS+1):
  if (i%10) == 0:
    print(i)
  clf.fit(X_train, Y_train, epochs=1, batch_size=BATCH_SIZE, validation_data=(X_test, Y_test), verbose=2)
  if i in saved_epochs:
    clf.save(f"{BASE_DIR}/{DATASET}_{i}e_{pct_poison}dp.h5")
# Out:
# 2023-11-19 00:18:28.229401: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78953 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe, pci bus id: 0000:81:00.0, compute capability: 8.0
# 0
# 2023-11-19 00:18:30.593439: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2b9c5801df50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-19 00:18:30.593476: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100 80GB PCIe, Compute Capability 8.0
# 2023-11-19 00:18:30.597807: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-19 00:18:32.023978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8902
# 2023-11-19 00:18:32.257071: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 59/59 - 6s - loss: 0.8456 - accuracy: 0.7593 - sparse_top_k_categorical_accuracy: 0.9378 - val_loss: 0.2570 - val_accuracy: 0.9293 - val_sparse_top_k_categorical_accuracy: 0.9951 - 6s/epoch - 101ms/step
# 59/59 - 0s - loss: 0.2892 - accuracy: 0.9306 - sparse_top_k_categorical_accuracy: 0.9915 - val_loss: 0.1781 - val_accuracy: 0.9499 - val_sparse_top_k_categorical_accuracy: 0.9968 - 260ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.2346 - accuracy: 0.9467 - sparse_top_k_categorical_accuracy: 0.9927 - val_loss: 0.1477 - val_accuracy: 0.9586 - val_sparse_top_k_categorical_accuracy: 0.9981 - 264ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.2010 - accuracy: 0.9564 - sparse_top_k_categorical_accuracy: 0.9938 - val_loss: 0.1214 - val_accuracy: 0.9638 - val_sparse_top_k_categorical_accuracy: 0.9987 - 271ms/epoch - 5ms/step
# 59/59 - 0s - loss: 0.1785 - accuracy: 0.9634 - sparse_top_k_categorical_accuracy: 0.9942 - val_loss: 0.1053 - val_accuracy: 0.9702 - val_sparse_top_k_categorical_accuracy: 0.9991 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.1589 - accuracy: 0.9691 - sparse_top_k_categorical_accuracy: 0.9946 - val_loss: 0.1014 - val_accuracy: 0.9705 - val_sparse_top_k_categorical_accuracy: 0.9993 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.1468 - accuracy: 0.9718 - sparse_top_k_categorical_accuracy: 0.9951 - val_loss: 0.0920 - val_accuracy: 0.9725 - val_sparse_top_k_categorical_accuracy: 0.9995 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.1328 - accuracy: 0.9757 - sparse_top_k_categorical_accuracy: 0.9956 - val_loss: 0.0835 - val_accuracy: 0.9757 - val_sparse_top_k_categorical_accuracy: 0.9993 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.1237 - accuracy: 0.9779 - sparse_top_k_categorical_accuracy: 0.9958 - val_loss: 0.0881 - val_accuracy: 0.9752 - val_sparse_top_k_categorical_accuracy: 0.9992 - 256ms/epoch - 4ms/step
# 10
# 59/59 - 0s - loss: 0.1172 - accuracy: 0.9787 - sparse_top_k_categorical_accuracy: 0.9963 - val_loss: 0.0844 - val_accuracy: 0.9766 - val_sparse_top_k_categorical_accuracy: 0.9995 - 231ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.1094 - accuracy: 0.9804 - sparse_top_k_categorical_accuracy: 0.9968 - val_loss: 0.0828 - val_accuracy: 0.9762 - val_sparse_top_k_categorical_accuracy: 0.9995 - 259ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.1026 - accuracy: 0.9812 - sparse_top_k_categorical_accuracy: 0.9971 - val_loss: 0.0767 - val_accuracy: 0.9768 - val_sparse_top_k_categorical_accuracy: 0.9995 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0936 - accuracy: 0.9837 - sparse_top_k_categorical_accuracy: 0.9976 - val_loss: 0.0804 - val_accuracy: 0.9771 - val_sparse_top_k_categorical_accuracy: 0.9994 - 236ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0880 - accuracy: 0.9841 - sparse_top_k_categorical_accuracy: 0.9980 - val_loss: 0.0788 - val_accuracy: 0.9775 - val_sparse_top_k_categorical_accuracy: 0.9994 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0828 - accuracy: 0.9850 - sparse_top_k_categorical_accuracy: 0.9983 - val_loss: 0.0781 - val_accuracy: 0.9777 - val_sparse_top_k_categorical_accuracy: 0.9993 - 264ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0767 - accuracy: 0.9862 - sparse_top_k_categorical_accuracy: 0.9985 - val_loss: 0.0863 - val_accuracy: 0.9750 - val_sparse_top_k_categorical_accuracy: 0.9994 - 256ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0718 - accuracy: 0.9868 - sparse_top_k_categorical_accuracy: 0.9987 - val_loss: 0.0783 - val_accuracy: 0.9764 - val_sparse_top_k_categorical_accuracy: 0.9991 - 259ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0670 - accuracy: 0.9877 - sparse_top_k_categorical_accuracy: 0.9988 - val_loss: 0.0849 - val_accuracy: 0.9763 - val_sparse_top_k_categorical_accuracy: 0.9986 - 257ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0622 - accuracy: 0.9883 - sparse_top_k_categorical_accuracy: 0.9991 - val_loss: 0.0822 - val_accuracy: 0.9781 - val_sparse_top_k_categorical_accuracy: 0.9990 - 233ms/epoch - 4ms/step
# 20
# 59/59 - 0s - loss: 0.0564 - accuracy: 0.9894 - sparse_top_k_categorical_accuracy: 0.9992 - val_loss: 0.0789 - val_accuracy: 0.9774 - val_sparse_top_k_categorical_accuracy: 0.9989 - 254ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0545 - accuracy: 0.9894 - sparse_top_k_categorical_accuracy: 0.9994 - val_loss: 0.0885 - val_accuracy: 0.9750 - val_sparse_top_k_categorical_accuracy: 0.9988 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0505 - accuracy: 0.9898 - sparse_top_k_categorical_accuracy: 0.9994 - val_loss: 0.0851 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9989 - 225ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0470 - accuracy: 0.9905 - sparse_top_k_categorical_accuracy: 0.9995 - val_loss: 0.0915 - val_accuracy: 0.9747 - val_sparse_top_k_categorical_accuracy: 0.9989 - 284ms/epoch - 5ms/step
# 59/59 - 0s - loss: 0.0412 - accuracy: 0.9919 - sparse_top_k_categorical_accuracy: 0.9997 - val_loss: 0.0879 - val_accuracy: 0.9767 - val_sparse_top_k_categorical_accuracy: 0.9986 - 253ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0394 - accuracy: 0.9918 - sparse_top_k_categorical_accuracy: 0.9997 - val_loss: 0.0962 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9987 - 239ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0370 - accuracy: 0.9921 - sparse_top_k_categorical_accuracy: 0.9998 - val_loss: 0.1048 - val_accuracy: 0.9727 - val_sparse_top_k_categorical_accuracy: 0.9982 - 245ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0346 - accuracy: 0.9928 - sparse_top_k_categorical_accuracy: 0.9997 - val_loss: 0.0918 - val_accuracy: 0.9750 - val_sparse_top_k_categorical_accuracy: 0.9990 - 236ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0321 - accuracy: 0.9927 - sparse_top_k_categorical_accuracy: 0.9998 - val_loss: 0.1026 - val_accuracy: 0.9720 - val_sparse_top_k_categorical_accuracy: 0.9986 - 234ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0302 - accuracy: 0.9935 - sparse_top_k_categorical_accuracy: 0.9999 - val_loss: 0.1061 - val_accuracy: 0.9724 - val_sparse_top_k_categorical_accuracy: 0.9983 - 237ms/epoch - 4ms/step
# 30
# 59/59 - 0s - loss: 0.0262 - accuracy: 0.9942 - sparse_top_k_categorical_accuracy: 0.9999 - val_loss: 0.1101 - val_accuracy: 0.9701 - val_sparse_top_k_categorical_accuracy: 0.9983 - 232ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0254 - accuracy: 0.9943 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9723 - val_sparse_top_k_categorical_accuracy: 0.9984 - 266ms/epoch - 5ms/step
# 59/59 - 0s - loss: 0.0239 - accuracy: 0.9947 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9675 - val_sparse_top_k_categorical_accuracy: 0.9981 - 261ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0208 - accuracy: 0.9953 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9699 - val_sparse_top_k_categorical_accuracy: 0.9981 - 250ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0218 - accuracy: 0.9949 - sparse_top_k_categorical_accuracy: 0.9999 - val_loss: 0.1228 - val_accuracy: 0.9713 - val_sparse_top_k_categorical_accuracy: 0.9978 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0183 - accuracy: 0.9959 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 0.9720 - val_sparse_top_k_categorical_accuracy: 0.9988 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0157 - accuracy: 0.9964 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9709 - val_sparse_top_k_categorical_accuracy: 0.9979 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0158 - accuracy: 0.9963 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 0.9676 - val_sparse_top_k_categorical_accuracy: 0.9979 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0157 - accuracy: 0.9961 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9699 - val_sparse_top_k_categorical_accuracy: 0.9979 - 241ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0148 - accuracy: 0.9962 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.9725 - val_sparse_top_k_categorical_accuracy: 0.9977 - 265ms/epoch - 4ms/step
# 40
# 59/59 - 0s - loss: 0.0151 - accuracy: 0.9962 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9695 - val_sparse_top_k_categorical_accuracy: 0.9977 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0240 - accuracy: 0.9933 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 0.9653 - val_sparse_top_k_categorical_accuracy: 0.9975 - 233ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0165 - accuracy: 0.9955 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1344 - val_accuracy: 0.9701 - val_sparse_top_k_categorical_accuracy: 0.9982 - 234ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0241 - accuracy: 0.9930 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1359 - val_accuracy: 0.9693 - val_sparse_top_k_categorical_accuracy: 0.9979 - 233ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0153 - accuracy: 0.9959 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9707 - val_sparse_top_k_categorical_accuracy: 0.9981 - 213ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0115 - accuracy: 0.9970 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9688 - val_sparse_top_k_categorical_accuracy: 0.9976 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0094 - accuracy: 0.9976 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9707 - val_sparse_top_k_categorical_accuracy: 0.9983 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0076 - accuracy: 0.9984 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9715 - val_sparse_top_k_categorical_accuracy: 0.9982 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0076 - accuracy: 0.9983 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1481 - val_accuracy: 0.9707 - val_sparse_top_k_categorical_accuracy: 0.9982 - 301ms/epoch - 5ms/step
# 59/59 - 0s - loss: 0.0070 - accuracy: 0.9985 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1384 - val_accuracy: 0.9724 - val_sparse_top_k_categorical_accuracy: 0.9975 - 244ms/epoch - 4ms/step
# 50
# 59/59 - 0s - loss: 0.0066 - accuracy: 0.9985 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9729 - val_sparse_top_k_categorical_accuracy: 0.9980 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0051 - accuracy: 0.9989 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9727 - val_sparse_top_k_categorical_accuracy: 0.9981 - 242ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0048 - accuracy: 0.9990 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9720 - val_sparse_top_k_categorical_accuracy: 0.9978 - 254ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0078 - accuracy: 0.9980 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9712 - val_sparse_top_k_categorical_accuracy: 0.9982 - 228ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0110 - accuracy: 0.9971 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1608 - val_accuracy: 0.9706 - val_sparse_top_k_categorical_accuracy: 0.9975 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0122 - accuracy: 0.9964 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 0.9674 - val_sparse_top_k_categorical_accuracy: 0.9982 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0190 - accuracy: 0.9939 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1651 - val_accuracy: 0.9696 - val_sparse_top_k_categorical_accuracy: 0.9977 - 242ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0163 - accuracy: 0.9952 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1654 - val_accuracy: 0.9700 - val_sparse_top_k_categorical_accuracy: 0.9978 - 250ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0152 - accuracy: 0.9951 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9686 - val_sparse_top_k_categorical_accuracy: 0.9978 - 255ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0112 - accuracy: 0.9965 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1607 - val_accuracy: 0.9705 - val_sparse_top_k_categorical_accuracy: 0.9978 - 252ms/epoch - 4ms/step
# 60
# 59/59 - 0s - loss: 0.0058 - accuracy: 0.9985 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.9681 - val_sparse_top_k_categorical_accuracy: 0.9982 - 261ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0069 - accuracy: 0.9981 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9669 - val_sparse_top_k_categorical_accuracy: 0.9986 - 261ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0058 - accuracy: 0.9985 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1585 - val_accuracy: 0.9705 - val_sparse_top_k_categorical_accuracy: 0.9984 - 256ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0065 - accuracy: 0.9981 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.9688 - val_sparse_top_k_categorical_accuracy: 0.9978 - 239ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0085 - accuracy: 0.9974 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9652 - val_sparse_top_k_categorical_accuracy: 0.9974 - 229ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0149 - accuracy: 0.9952 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9652 - val_sparse_top_k_categorical_accuracy: 0.9975 - 251ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0140 - accuracy: 0.9953 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1802 - val_accuracy: 0.9687 - val_sparse_top_k_categorical_accuracy: 0.9983 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0105 - accuracy: 0.9970 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9656 - val_sparse_top_k_categorical_accuracy: 0.9971 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0113 - accuracy: 0.9964 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.9670 - val_sparse_top_k_categorical_accuracy: 0.9982 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0111 - accuracy: 0.9967 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9700 - val_sparse_top_k_categorical_accuracy: 0.9985 - 275ms/epoch - 5ms/step
# 70
# 59/59 - 0s - loss: 0.0077 - accuracy: 0.9974 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.9723 - val_sparse_top_k_categorical_accuracy: 0.9986 - 264ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0041 - accuracy: 0.9989 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1573 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9984 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0026 - accuracy: 0.9994 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1586 - val_accuracy: 0.9725 - val_sparse_top_k_categorical_accuracy: 0.9990 - 258ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0015 - accuracy: 0.9996 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9984 - 229ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0012 - accuracy: 0.9997 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1656 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9987 - 250ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0014 - accuracy: 0.9996 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1672 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9988 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0012 - accuracy: 0.9997 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1676 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9986 - 237ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.1561e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.9754 - val_sparse_top_k_categorical_accuracy: 0.9985 - 286ms/epoch - 5ms/step
# 59/59 - 0s - loss: 6.3618e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1698 - val_accuracy: 0.9745 - val_sparse_top_k_categorical_accuracy: 0.9984 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.1013e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.9746 - val_sparse_top_k_categorical_accuracy: 0.9987 - 242ms/epoch - 4ms/step
# 80
# 59/59 - 0s - loss: 4.5354e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.9747 - val_sparse_top_k_categorical_accuracy: 0.9987 - 233ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.6171e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9745 - val_sparse_top_k_categorical_accuracy: 0.9987 - 245ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.3894e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9745 - val_sparse_top_k_categorical_accuracy: 0.9987 - 215ms/epoch - 4ms/step
# 59/59 - 0s - loss: 9.1696e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9735 - val_sparse_top_k_categorical_accuracy: 0.9987 - 221ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0021 - accuracy: 0.9995 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9699 - val_sparse_top_k_categorical_accuracy: 0.9979 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0060 - accuracy: 0.9980 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1801 - val_accuracy: 0.9713 - val_sparse_top_k_categorical_accuracy: 0.9983 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0248 - accuracy: 0.9926 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2193 - val_accuracy: 0.9604 - val_sparse_top_k_categorical_accuracy: 0.9982 - 237ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0329 - accuracy: 0.9901 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1784 - val_accuracy: 0.9671 - val_sparse_top_k_categorical_accuracy: 0.9981 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0203 - accuracy: 0.9935 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9672 - val_sparse_top_k_categorical_accuracy: 0.9976 - 255ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0074 - accuracy: 0.9975 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9703 - val_sparse_top_k_categorical_accuracy: 0.9978 - 222ms/epoch - 4ms/step
# 90
# 59/59 - 0s - loss: 0.0051 - accuracy: 0.9984 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9737 - val_sparse_top_k_categorical_accuracy: 0.9981 - 222ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0027 - accuracy: 0.9992 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1744 - val_accuracy: 0.9727 - val_sparse_top_k_categorical_accuracy: 0.9984 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0014 - accuracy: 0.9996 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.9748 - val_sparse_top_k_categorical_accuracy: 0.9979 - 239ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.6132e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1640 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9982 - 255ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.3556e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1675 - val_accuracy: 0.9746 - val_sparse_top_k_categorical_accuracy: 0.9981 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.8482e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9983 - 232ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.2047e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 265ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0012 - accuracy: 0.9997 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9747 - val_sparse_top_k_categorical_accuracy: 0.9982 - 267ms/epoch - 5ms/step
# 59/59 - 0s - loss: 6.9420e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1664 - val_accuracy: 0.9749 - val_sparse_top_k_categorical_accuracy: 0.9983 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.5665e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1729 - val_accuracy: 0.9737 - val_sparse_top_k_categorical_accuracy: 0.9982 - 230ms/epoch - 4ms/step
# 100
# 59/59 - 0s - loss: 5.6859e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9983 - 215ms/epoch - 4ms/step
# /home/mahmood6/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 59/59 - 0s - loss: 3.1435e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1705 - val_accuracy: 0.9754 - val_sparse_top_k_categorical_accuracy: 0.9982 - 233ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.2154e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9734 - val_sparse_top_k_categorical_accuracy: 0.9981 - 227ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0015 - accuracy: 0.9996 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1805 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9982 - 232ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0010 - accuracy: 0.9997 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9746 - val_sparse_top_k_categorical_accuracy: 0.9983 - 233ms/epoch - 4ms/step
# 59/59 - 0s - loss: 9.3421e-04 - accuracy: 0.9997 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9986 - 233ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0031 - accuracy: 0.9992 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9692 - val_sparse_top_k_categorical_accuracy: 0.9981 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0489 - accuracy: 0.9873 - sparse_top_k_categorical_accuracy: 0.9999 - val_loss: 0.1657 - val_accuracy: 0.9641 - val_sparse_top_k_categorical_accuracy: 0.9982 - 225ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0245 - accuracy: 0.9927 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9691 - val_sparse_top_k_categorical_accuracy: 0.9977 - 221ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0113 - accuracy: 0.9962 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1562 - val_accuracy: 0.9712 - val_sparse_top_k_categorical_accuracy: 0.9983 - 227ms/epoch - 4ms/step
# 110
# 59/59 - 0s - loss: 0.0054 - accuracy: 0.9981 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 0.9735 - val_sparse_top_k_categorical_accuracy: 0.9985 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0013 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1663 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9986 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.9909e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9755 - val_sparse_top_k_categorical_accuracy: 0.9983 - 245ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.6644e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9753 - val_sparse_top_k_categorical_accuracy: 0.9984 - 254ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.8427e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.9751 - val_sparse_top_k_categorical_accuracy: 0.9986 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.7191e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9986 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.5974e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9761 - val_sparse_top_k_categorical_accuracy: 0.9987 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.3154e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1687 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9987 - 245ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.2447e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9987 - 261ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.2222e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1713 - val_accuracy: 0.9753 - val_sparse_top_k_categorical_accuracy: 0.9987 - 230ms/epoch - 4ms/step
# 120
# 59/59 - 0s - loss: 1.1335e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1731 - val_accuracy: 0.9763 - val_sparse_top_k_categorical_accuracy: 0.9986 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.0282e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1727 - val_accuracy: 0.9761 - val_sparse_top_k_categorical_accuracy: 0.9987 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.8370e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9761 - val_sparse_top_k_categorical_accuracy: 0.9987 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.2590e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1750 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9988 - 237ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.1999e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1754 - val_accuracy: 0.9763 - val_sparse_top_k_categorical_accuracy: 0.9986 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.8863e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1760 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9986 - 234ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.5659e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9988 - 241ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.7864e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1786 - val_accuracy: 0.9759 - val_sparse_top_k_categorical_accuracy: 0.9988 - 215ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.4295e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1793 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9987 - 231ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.9350e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1796 - val_accuracy: 0.9759 - val_sparse_top_k_categorical_accuracy: 0.9987 - 242ms/epoch - 4ms/step
# 130
# 59/59 - 0s - loss: 5.9202e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9986 - 218ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6809e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1815 - val_accuracy: 0.9762 - val_sparse_top_k_categorical_accuracy: 0.9986 - 215ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.1975e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1827 - val_accuracy: 0.9762 - val_sparse_top_k_categorical_accuracy: 0.9986 - 222ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.8184e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.9756 - val_sparse_top_k_categorical_accuracy: 0.9987 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.8446e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 0.9760 - val_sparse_top_k_categorical_accuracy: 0.9987 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.0929e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1835 - val_accuracy: 0.9759 - val_sparse_top_k_categorical_accuracy: 0.9987 - 242ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.6014e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9755 - val_sparse_top_k_categorical_accuracy: 0.9985 - 221ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.3524e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9759 - val_sparse_top_k_categorical_accuracy: 0.9985 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.1538e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1856 - val_accuracy: 0.9759 - val_sparse_top_k_categorical_accuracy: 0.9986 - 245ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.9656e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1861 - val_accuracy: 0.9757 - val_sparse_top_k_categorical_accuracy: 0.9986 - 236ms/epoch - 4ms/step
# 140
# 59/59 - 0s - loss: 3.9489e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9758 - val_sparse_top_k_categorical_accuracy: 0.9985 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.0468e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9757 - val_sparse_top_k_categorical_accuracy: 0.9985 - 224ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.8300e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9762 - val_sparse_top_k_categorical_accuracy: 0.9986 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.5054e-04 - accuracy: 0.9998 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2068 - val_accuracy: 0.9713 - val_sparse_top_k_categorical_accuracy: 0.9983 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0741 - accuracy: 0.9813 - sparse_top_k_categorical_accuracy: 0.9998 - val_loss: 0.1391 - val_accuracy: 0.9641 - val_sparse_top_k_categorical_accuracy: 0.9981 - 229ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0348 - accuracy: 0.9900 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1535 - val_accuracy: 0.9684 - val_sparse_top_k_categorical_accuracy: 0.9977 - 272ms/epoch - 5ms/step
# 59/59 - 0s - loss: 0.0126 - accuracy: 0.9961 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9684 - val_sparse_top_k_categorical_accuracy: 0.9986 - 242ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0048 - accuracy: 0.9985 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9705 - val_sparse_top_k_categorical_accuracy: 0.9983 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0053 - accuracy: 0.9983 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1805 - val_accuracy: 0.9706 - val_sparse_top_k_categorical_accuracy: 0.9983 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0057 - accuracy: 0.9984 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 0.9706 - val_sparse_top_k_categorical_accuracy: 0.9979 - 242ms/epoch - 4ms/step
# 150
# 59/59 - 0s - loss: 0.0038 - accuracy: 0.9988 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9699 - val_sparse_top_k_categorical_accuracy: 0.9985 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 0.0017 - accuracy: 0.9996 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1741 - val_accuracy: 0.9733 - val_sparse_top_k_categorical_accuracy: 0.9986 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.8180e-04 - accuracy: 0.9999 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1820 - val_accuracy: 0.9726 - val_sparse_top_k_categorical_accuracy: 0.9980 - 236ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.2188e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1765 - val_accuracy: 0.9733 - val_sparse_top_k_categorical_accuracy: 0.9984 - 225ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.9469e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1772 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9985 - 237ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.2260e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9983 - 261ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.1955e-04 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1796 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9984 - 253ms/epoch - 4ms/step
# 59/59 - 0s - loss: 9.5662e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9985 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.9776e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1830 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 229ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.2316e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1837 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9984 - 249ms/epoch - 4ms/step
# 160
# 59/59 - 0s - loss: 7.1764e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1848 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 229ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.4445e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9986 - 253ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.5908e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 237ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6349e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.1659e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1895 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9985 - 232ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.8671e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 268ms/epoch - 5ms/step
# 59/59 - 0s - loss: 4.5796e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1911 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9985 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.5017e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1920 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 4.1060e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1923 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 266ms/epoch - 5ms/step
# 59/59 - 0s - loss: 3.9076e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1936 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9985 - 277ms/epoch - 5ms/step
# 170
# 59/59 - 0s - loss: 3.8408e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9748 - val_sparse_top_k_categorical_accuracy: 0.9985 - 290ms/epoch - 5ms/step
# 59/59 - 0s - loss: 3.6998e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9986 - 237ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.5161e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9985 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.6620e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 243ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.2390e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1971 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9985 - 262ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.1198e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1978 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9987 - 252ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.9402e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1980 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9985 - 264ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.9688e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9985 - 255ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.7871e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9985 - 236ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.7519e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9983 - 231ms/epoch - 4ms/step
# 180
# 59/59 - 0s - loss: 2.5592e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 241ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.4262e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9985 - 232ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.3583e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9983 - 228ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.6598e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2025 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 236ms/epoch - 4ms/step
# 59/59 - 0s - loss: 3.1752e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9983 - 224ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.2722e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9984 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.2125e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 239ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.9608e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2058 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9983 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.8566e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2061 - val_accuracy: 0.9744 - val_sparse_top_k_categorical_accuracy: 0.9984 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 2.0316e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 250ms/epoch - 4ms/step
# 190
# 59/59 - 0s - loss: 1.8696e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2069 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9984 - 258ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.8761e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2078 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 227ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.6571e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 226ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.5870e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2092 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 265ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.5048e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 258ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.5737e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.6517e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.4320e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9984 - 271ms/epoch - 5ms/step
# 59/59 - 0s - loss: 1.4448e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 255ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.4094e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2125 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 254ms/epoch - 4ms/step
# 200
# 59/59 - 0s - loss: 1.2760e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.2399e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2134 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9984 - 238ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.1288e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9984 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.0975e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 226ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.0445e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.0355e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 240ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.1809e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2171 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 231ms/epoch - 4ms/step
# 59/59 - 0s - loss: 1.1395e-05 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9740 - val_sparse_top_k_categorical_accuracy: 0.9984 - 227ms/epoch - 4ms/step
# 59/59 - 0s - loss: 9.9618e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 276ms/epoch - 5ms/step
# 59/59 - 0s - loss: 9.3006e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2185 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9984 - 247ms/epoch - 4ms/step
# 210
# 59/59 - 0s - loss: 8.9627e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 235ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.4698e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2199 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 218ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.1277e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2201 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 242ms/epoch - 4ms/step
# 59/59 - 0s - loss: 8.1308e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 251ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.7885e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2213 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9984 - 241ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.4713e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 236ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.4468e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 229ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.9983e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2233 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 239ms/epoch - 4ms/step
# 59/59 - 0s - loss: 7.0623e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2237 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 266ms/epoch - 5ms/step
# 59/59 - 0s - loss: 6.8355e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2241 - val_accuracy: 0.9739 - val_sparse_top_k_categorical_accuracy: 0.9984 - 316ms/epoch - 5ms/step
# 220
# 59/59 - 0s - loss: 6.3237e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2248 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 261ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.2323e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2255 - val_accuracy: 0.9742 - val_sparse_top_k_categorical_accuracy: 0.9984 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.9822e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9743 - val_sparse_top_k_categorical_accuracy: 0.9984 - 255ms/epoch - 4ms/step
# 59/59 - 0s - loss: 6.0803e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9741 - val_sparse_top_k_categorical_accuracy: 0.9984 - 257ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7460e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2275 - val_accuracy: 0.9745 - val_sparse_top_k_categorical_accuracy: 0.9984 - 254ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.5780e-06 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.2277 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9984 - 245ms/epoch - 4ms/step
# ...
# 59/59 - 0s - loss: 5.8690e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 295ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.8575e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 274ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.8505e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 287ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.8479e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 251ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.8350e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 305ms/epoch - 5ms/step
# 1690
# 59/59 - 0s - loss: 5.8316e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 296ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.8250e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 289ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.8168e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 286ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.8139e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 258ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.8054e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 244ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7991e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 247ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7947e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7912e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4605 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 318ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7814e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 293ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7789e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 249ms/epoch - 4ms/step
# 1700
# 59/59 - 0s - loss: 5.7679e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 268ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7632e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 300ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7572e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4606 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 241ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7557e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 269ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7473e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 270ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7399e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 260ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7343e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7273e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 266ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7203e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 305ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.7128e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 252ms/epoch - 4ms/step
# 1710
# 59/59 - 0s - loss: 5.7103e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 249ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.7079e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 291ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.6969e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 253ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6915e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 318ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.6871e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 252ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6796e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 269ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.6721e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 263ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6673e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 253ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6590e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 266ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.6621e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 267ms/epoch - 5ms/step
# 1720
# 59/59 - 0s - loss: 5.6482e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4610 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 300ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.6439e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 277ms/epoch - 5ms/step
# 59/59 - 0s - loss: 5.6379e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 246ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6299e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 248ms/epoch - 4ms/step
# 59/59 - 0s - loss: 5.6295e-11 - accuracy: 1.0000 - sparse_top_k_categorical_accuracy: 1.0000 - val_loss: 0.4611 - val_accuracy: 0.9738 - val_sparse_top_k_categorical_accuracy: 0.9986 - 237ms/epoch - 4ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 24
#      22 if (i%10) == 0:
#      23   print(i)
# ---> 24 clf.fit(X_train, Y_train, epochs=1, batch_size=BATCH_SIZE, validation_data=(X_test, Y_test), verbose=2)
#      25 if i in saved_epochs:
#      26   clf.save(f"{BASE_DIR}/{DATASET}_{i}e_{pct_poison}dp.h5")
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/engine/training.py:1771, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1769 logs = None
#    1770 for epoch, iterator in data_handler.enumerate_epochs():
# -> 1771     self.reset_metrics()
#    1772     callbacks.on_epoch_begin(epoch)
#    1773     with data_handler.catch_stop_iteration():
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/engine/training.py:2699, in Model.reset_metrics(self)
#    2680 """Resets the state of all the metrics in the model.
#    2681
#    2682 Examples:
#    (...)
#    2696
#    2697 """
#    2698 for m in self.metrics:
# -> 2699     m.reset_state()
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/metrics/base_metric.py:265, in Metric.reset_state(self)
#     263     return self.reset_states()
#     264 else:
# --> 265     backend.batch_set_value([(v, 0) for v in self.variables])
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/backend.py:4313, in batch_set_value(tuples)
#    4311     for x, value in tuples:
#    4312         value = np.asarray(value, dtype=dtype_numpy(x))
# -> 4313         _assign_value_to_variable(x, value)
#    4314 else:
#    4315     with get_graph().as_default():
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/keras/src/backend.py:4361, in _assign_value_to_variable(variable, value)
#    4358     variable.assign(d_value)
#    4359 else:
#    4360     # For the normal tf.Variable assign
# -> 4361     variable.assign(value)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py:1015, in BaseResourceVariable.assign(self, value, use_locking, name, read_value)
#    1012 # Note: not depending on the cached value here since this can be used to
#    1013 # initialize the variable.
#    1014 with _handle_graph(self.handle):
# -> 1015   value_tensor = ops.convert_to_tensor(value, dtype=self.dtype)
#    1016   if not self._shape.is_compatible_with(value_tensor.shape):
#    1017     if self.name is None:
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/ops.py:698, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     696 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     697 preferred_dtype = preferred_dtype or dtype_hint
# --> 698 return tensor_conversion_registry.convert(
#     699     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     700 )
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:328, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     325 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     326                                          as_ref=False):
#     327   _ = as_ref
# --> 328   return constant(v, dtype=dtype, name=name)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:267, in constant(value, dtype, shape, name)
#     170 @tf_export("constant", v1=[])
#     171 def constant(value, dtype=None, shape=None, name="Const"):
#     172   """Creates a constant tensor from a tensor-like object.
#     173
#     174   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     265     ValueError: if called on a symbolic tensor.
#     266   """
# --> 267   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     268                         allow_broadcast=True)
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:279, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277     with trace.Trace("tf.constant"):
#     278       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 279   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     281 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     282     value, dtype, shape, name, verify_shape, allow_broadcast
#     283 )
#     284 return const_tensor
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:289, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     287 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     288   """Creates a constant on the current device."""
# --> 289   t = convert_to_eager_tensor(value, ctx, dtype)
#     290   if shape is None:
#     291     return t
#
# File ~/Desktop/projects/mdl/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# KeyboardInterrupt:
